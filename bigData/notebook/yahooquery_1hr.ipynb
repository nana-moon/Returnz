# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import yahooquery as yq
from yahooquery import Ticker
from datetime import datetime, timedelta
s1 = pd.read_csv("./valid_company_list.csv", encoding='euc-kr')
s1 = s1.iloc[:, 1]
s1 = s1.values
symbols = s1.tolist()

# %%
# 1시간단위 데이터 추출
interval='1h'
start = datetime.today()-timedelta(days=729)
end = datetime.today()
df = pd.DataFrame()

for company in symbols:
    ticker = Ticker(company)
    a = ticker.history(start=start, end=end, interval=interval)
    # 멀티인덱스 수정
    company_datas = dict()
    tmp_df = a.loc[company]
    company_datas[company] = tmp_df
    company_datas[company]["date"] = company_datas[company].index
    company_datas[company]["symbol"] = company
    df = pd.concat([df, company_datas[company]], axis=0)
    print(company, '성공')
df
# Out:
# 095570.KS 성공
# 006840.KS 성공
# 282330.KS 성공
# 027410.KS 성공
# 138930.KS 성공
# 001465.KS 성공
# 001460.KS 성공
# 001045.KS 성공
# 00104K.KS 성공
# 001040.KS 성공
# 011155.KS 성공
# 011150.KS 성공
# 000590.KS 성공
# 012030.KS 성공
# 016610.KS 성공
# 005830.KS 성공
# 000995.KS 성공
# 000990.KS 성공
# 139130.KS 성공
# 001530.KS 성공
# 000215.KS 성공
# 001880.KS 성공
# 000210.KS 성공
# 37550K.KS 성공
# 37550L.KS 성공
# 375500.KS 성공
# 155660.KS 성공
# 069730.KS 성공
# 017940.KS 성공
# 365550.KS 성공
# 383220.KS 성공
# 007700.KS 성공
# 078935.KS 성공
# 006360.KS 성공
# 078930.KS 성공
# 012630.KS 성공
# 294870.KS 성공
# 097230.KS 성공
# 014790.KS 성공
# 204320.KS 성공
# 060980.KS 성공
# 003560.KS 성공
# 175330.KS 성공
# 234080.KS 성공
# 001065.KS 성공
# 001067.KS 성공
# 001060.KS 성공
# 096760.KS 성공
# 105560.KS 성공
# 432320.KS 성공
# 009070.KS 성공
# 016380.KS 성공
# 001390.KS 성공
# 033180.KS 성공
# 001940.KS 성공
# 025000.KS 성공
# 092230.KS 성공
# 000040.KS 성공
# 093050.KS 성공
# 003555.KS 성공
# 034220.KS 성공
# 003550.KS 성공
# 051905.KS 성공
# 051900.KS 성공
# 373220.KS 성공
# 032640.KS 성공
# ...

# %%
df1 = df.drop(df.columns[[5]], axis=1)
df1.to_csv("C:/Users/SSAFY/Downloads/drafts2.csv", sep=',', encoding='utf-8')
